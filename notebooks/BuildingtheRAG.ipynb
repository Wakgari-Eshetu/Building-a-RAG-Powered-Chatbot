# %% [markdown]
# # Task 3: RAG Core Logic & Qualitative Evaluation
#
# This notebook evaluates the Retrieval-Augmented Generation (RAG) system built
# using precomputed complaint embeddings provided in `complaints_embeddings.parquet`.
#
# The goal is to assess how well the system retrieves relevant complaint excerpts
# and generates grounded, accurate answers to user questions.

# %%
import pandas as pd

df = pd.read_parquet(
    "../data/raw/complaint_embeddings.parquet",
#columns=["embedding", "complaint_text"]  # only necessary columns
)

# %%
df.columns
df.info
# Out:
# <bound method DataFrame.info of                  id                                           document  \
# 0        14069121_0  a card was opened under my name by a fraudster...
# 1        14061897_0  i made the mistake of using my wellsfargo debi...
# 2        14061897_1  and got a letter stating my dispute was reject...
# 3        14047085_0  dear cfpb, i have a secured credit card with c...
# 4        14047085_1  y confirmation whatsoever to report to the pol...
# ...             ...                                                ...
# 1375322   6238123_1  tract i had hey and i explained to them that i...
# 1375323   6238123_2  my balance and i have the documents to show th...
# 1375324   6238123_3  alled a crew and then looking back at the cont...
# 1375325   6238123_4  know my car was repossessed on now i've been c...
# 1375326   6238123_5                                               this
#
#                                                  embedding  \
# 0        [-0.04277738183736801, 0.025624370202422142, -...
# 1        [-0.05458317697048187, 0.10340359061956406, 0....
# 2        [-0.03491289168596268, 0.059216588735580444, 0...
# 3        [-0.010181158781051636, 0.02354264445602894, -...
# 4        [-0.017308838665485382, -0.007177562452852726,...
# ...                                                    ...
# 1375322  [-0.07657872885465622, 0.06277621537446976, 0....
# 1375323  [-0.05301162227988243, 0.1226310133934021, 0.0...
# 1375324  [-0.07775353640317917, 0.027862858027219772, 0...
# 1375325  [-0.04154370725154877, 0.07054945826530457, 0....
# 1375326  [-0.06774239987134933, 0.046260152012109756, -...
#
#                                                   metadata
# 0        {'chunk_index': 0, 'company': 'CITIBANK, N.A.'...
# 1        {'chunk_index': 0, 'company': 'WELLS FARGO & C...
# 2        {'chunk_index': 1, 'company': 'WELLS FARGO & C...
# 3        {'chunk_index': 0, 'company': 'CITIBANK, N.A.'...
# 4        {'chunk_index': 1, 'company': 'CITIBANK, N.A.'...
# ...                                                    ...
# 1375322  {'chunk_index': 1, 'company': 'Westlake Servic...
# 1375323  {'chunk_index': 2, 'company': 'Westlake Servic...
# 1375324  {'chunk_index': 3, 'company': 'Westlake Servic...
# 1375325  {'chunk_index': 4, 'company': 'Westlake Servic...
# 1375326  {'chunk_index': 5, 'company': 'Westlake Servic...
#
# [1375327 rows x 4 columns]>

# %%
import pandas as pd
import sys, os
sys.path.insert(0, os.path.abspath(".."))


from src.rag_pipeline import RAGPipeline

# %%
rag = RAGPipeline()
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Device set to use cpu

# %%
evaluation_questions = [
    "What are the most common credit card complaints?",
    "Do customers complain about late payment fees?",
    "What issues do customers face with loan approvals?",
    "Are there complaints related to customer service responsiveness?",
    "What fraud-related issues are mentioned in the complaints?",
    "Do customers report problems with interest rates?",
    "What issues are raised regarding account closures?"
]

# %%
results = []

for question in evaluation_questions:
    output = rag.run(question)
    
    results.append({
        "Question": question,
        "Generated Answer": output["answer"],
        "Retrieved Sources": " | ".join(output["sources"]),
        "Quality Score (1-5)": "",  # Fill manually
        "Comments / Analysis": ""   # Fill manually
    })

df = pd.DataFrame(results)
df
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
#                                             Question  \
# 0   What are the most common credit card complaints?
# 1     Do customers complain about late payment fees?
# 2  What issues do customers face with loan approv...
# 3  Are there complaints related to customer servi...
# 4  What fraud-related issues are mentioned in the...
# 5  Do customers report problems with interest rates?
# 6  What issues are raised regarding account closu...
#
#                                     Generated Answer  \
# 0  The most common credit card complaints are abo...
# 1  Yes, based on the context provided, the custom...
# 2  Customers have expressed concerns about being ...
# 3  Yes, based on the context provided, there are ...
# 4  The complaint mentions fraudulent transactions...
# 5  Yes, based on the context provided, customers ...
# 6  The customers raised issues regarding the sudd...
#
#                                    Retrieved Sources Quality Score (1-5)  \
# 0  any. i am sure that you had many other complai...
# 1  in their hands, not somewhere magically in lim...
# 2  thus ruining my chances for approvals with oth...
# 3  e about their customers that they hire custome...
# 4  stently since first reporting the fraud claim ...
# 5  interests rate they simply dont care to help c...
# 6  , and have never engaged in any suspicious or ...
#
#   Comments / Analysis
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %% [markdown]
# ## Evaluation Guidelines
#
# Quality Score:
# - **5** – Fully accurate, well-grounded, clear
# - **4** – Mostly correct, minor missing details
# - **3** – Partially correct or vague
# - **2** – Weak grounding or incomplete
# - **1** – Incorrect or hallucinated
#
# Fill in the Quality Score and Comments columns manually based on these criteria.

# %%
df.loc[0, "Quality Score (1-5)"] = 4
df.loc[0, "Comments / Analysis"] = "Answer is accurate and grounded but lacks specific examples."

df.loc[1, "Quality Score (1-5)"] = 5
df.loc[1, "Comments / Analysis"] = "Clearly explains late fee complaints using retrieved context."

df
# Out:
#                                             Question  \
# 0   What are the most common credit card complaints?
# 1     Do customers complain about late payment fees?
# 2  What issues do customers face with loan approv...
# 3  Are there complaints related to customer servi...
# 4  What fraud-related issues are mentioned in the...
# 5  Do customers report problems with interest rates?
# 6  What issues are raised regarding account closu...
#
#                                     Generated Answer  \
# 0  The most common credit card complaints are abo...
# 1  Yes, based on the context provided, the custom...
# 2  Customers have expressed concerns about being ...
# 3  Yes, based on the context provided, there are ...
# 4  The complaint mentions fraudulent transactions...
# 5  Yes, based on the context provided, customers ...
# 6  The customers raised issues regarding the sudd...
#
#                                    Retrieved Sources Quality Score (1-5)  \
# 0  any. i am sure that you had many other complai...                   4
# 1  in their hands, not somewhere magically in lim...                   5
# 2  thus ruining my chances for approvals with oth...
# 3  e about their customers that they hire custome...
# 4  stently since first reporting the fraud claim ...
# 5  interests rate they simply dont care to help c...
# 6  , and have never engaged in any suspicious or ...
#
#                                  Comments / Analysis
# 0  Answer is accurate and grounded but lacks spec...
# 1  Clearly explains late fee complaints using ret...
# 2
# 3
# 4
# 5
# 6

# %%
print(df.to_markdown(index=False))
# Out:
# | Question                                                         | Generated Answer                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           | Retrieved Sources                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           | Quality Score (1-5)   | Comments / Analysis                                           |
# |:-----------------------------------------------------------------|:-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:----------------------|:--------------------------------------------------------------|
# | What are the most common credit card complaints?                 | The most common credit card complaints are about the competence of the card issuer's customer service representatives, with Bank of America's credit card team receiving the most complaints (18% of the total). Other common complaints include issues with interest rates (10%), identity theft (7%), credit reporting (7%), and closing and canceling accounts (6%). The majority of complaints (60%) are resolved with an explanation from the card company. Complaints resulted in monetary relief 29% of the time and with some sort of non-monetary relief in another 10% of cases. | any. i am sure that you had many other complaints. i would like to get my money back and hope you will restrict them from operating a credit card scam. | ompetence of the bank of america credit card team. i have used many credit cards, and i have never encountered such issues, and have to talk to clueless representatives over and over again.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     | 4                     | Answer is accurate and grounded but lacks specific examples.  |
